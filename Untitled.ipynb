# %%
! pip install PyMySQL
! pip install ipython-sql
! pip install mysqlclient

# %%
import pymysql
import pandas as pd

# %%
db_name = "IIV"
db_host = "10.105.11.29"
db_username = "User1"
db_password = "test123"

try:
    conn = pymysql.connect(host = db_host,
                           port = int(3306),
                           user = db_username,
                           password = db_password,
                           db = db_name)
except e:
    print (e)
if conn:
    print ("connection successful")
else:
        print ("error")

# %% [markdown]
# Task 1: Comparison of international universities

# %% [markdown]
# •	Import the SQL file (Times World University Rankings (2011-2016)) from the course room and familiarise yourself with the database and the columns.
#
# •	The Female_Students column is given in %.
#
# •	Answer the following questions using SQL queries.

# %%
df = pd.read_sql_query("select * from Times_World_University_Rankings_2011_2016", con=conn)
df

# %% [markdown]
# 1. Which university (name) was ranked 13th in 2016?

# %%
df = pd.read_sql_query("YOUR SQL QUERY", con=conn)
df

# %% [markdown]
# 2. Write an SQL command that displays all entries with all columns where the female students were not recorded (= NULL).

# %%
df = pd.read_sql_query("YOUR SQL QUERY", con=conn)
df

# %% [markdown]
# 3. How many universities in the TOP 50 in 2015 are from the USA?

# %%
df = pd.read_sql_query("YOUR SQL QUERY", con=conn)
df

# %% [markdown]
# 4. What is the command for the average Student_Staff_Ratio for universities with a Total_Score greater than 75 that are not from South Korea across all years?

# %%
df = pd.read_sql_query("YOUR SQL QUERY", con=conn)
df

# %% [markdown]
# 5. Which command gives the country name and the average number of students per country in 2014?
# The column with the average number of students should be named "avgStudentsCountry" and the sorting should be done in descending order by "avgStundetsCountry".

# %%
df = pd.read_sql_query("YOUR SQL QUERY", con=conn)
df

# %% [markdown]
# 6. Try to find and analyse the University of Würzburg in the database.
# Which World_Rank and Total_Score could the University of Würzburg achieve in 2016?
# Note: The SQL file is an international data set, which is why the umlauts are not shown as German umlauts, but as percentage signs!

# %%
df = pd.read_sql_query("YOUR SQL QUERY", con=conn)
df

# %% [markdown]
# Task 2: Room planning at the university

# %% [markdown]
# The university consists of various university chairs. Corresponding staff members are assigned to each chair. The staff members are distributed among the available rooms of a chair

# %% [markdown]
# ![Bild1.png](attachment:Bild1.png)

# %%
df = pd.read_sql_query("select * from raum", con=conn)
df

# %% [markdown]
# 1. Show all rooms that have employees. Only the room_ID and the employee's last name shall be displayed. The results should be sorted by room_ID in descending order.

# %%
df = pd.read_sql_query("MY SQL QUERY", con=conn)
df

# %% [markdown]
# 2. In which rooms (including floor) is no employee currently working?

# %%
df = pd.read_sql_query("MY SQL QUERY", con=conn)
df

# %% [markdown]
# 3. Which university chairs employ more than 5 people?

# %%
df = pd.read_sql_query("MY SQL QUERY", con=conn)
df

# %% [markdown]
# 4. Do the staff of the "LEHRSTUHL FÜR FINANZWISSENSCHAFT" only have rooms on one floor?

# %%
df = pd.read_sql_query("MY SQL QUERY", con=conn)
df
